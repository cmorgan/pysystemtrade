# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pylab
figsize = (11, 7)
pylab.rcParams['figure.figsize'] = figsize
import pandas as pd
import numpy as np
import datetime
import pylab
# import seaborn as sns
figsize = (11, 7)
pylab.rcParams['figure.figsize'] = figsize
import datetime
from private.basesystem import futures_system
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
system = futures_system()

# %%
portfolio = system.accounts.portfolio()
# Out:
# Calculating pandl for portfolio
# Calculating pandl for instrument for EDOLLAR
# Loading csv data for EDOLLAR
# Calculating notional position for EDOLLAR
# Calculating diversification multiplier
# Calculating clean instrument weights
# Calculating raw instrument weights
# Calculating subsystem position for EDOLLAR
# Calculating volatility scalar for EDOLLAR
# Calculating instrument value vol for EDOLLAR
# Calculating instrument currency vol for EDOLLAR
# Getting block value for EDOLLAR
# Loading csv carry data for EDOLLAR
# Loading csv instrument config
# Calculating daily volatility for EDOLLAR
# Calculating daily prices for EDOLLAR
# Loading csv data for EDOLLAR
# Getting fx rates for EDOLLAR
# Getting vol target
# Loading csv instrument config
# Loading csv fx data
# Calculating combined forecast for EDOLLAR
# Calculating forecast weights for EDOLLAR
# Calculating raw forecast weights for EDOLLAR
# Calculating capped forecast for EDOLLAR carry
# ...

# %%
system.data._get_instrument_data()
# Out:
# Loading csv instrument config
#            Instrument  Pointsize AssetClass Currency
# Instrument
# CORN             CORN         50        Ags      USD
# LEANHOG       LEANHOG        400        Ags      USD
# LIVECOW       LIVECOW        400        Ags      USD
# SOYBEAN       SOYBEAN         50        Ags      USD
# WHEAT           WHEAT         50        Ags      USD
# KR10             KR10    1000000       Bond      KRW
# KR3               KR3    1000000       Bond      KRW
# BOBL             BOBL       1000       Bond      EUR
# BTP               BTP       1000       Bond      EUR
# BUND             BUND       1000       Bond      EUR
# OAT               OAT       1000       Bond      EUR
# SHATZ           SHATZ       1000       Bond      EUR
# US10             US10       1000       Bond      USD
# US2               US2       2000       Bond      USD
# US20             US20       1000       Bond      USD
# US5               US5       1000       Bond      USD
# ...

# %%
len(system.rawdata.daily_annualised_roll('EDOLLAR'))
# Out:
# 8405

# %%
system.data.daily_prices('GBP').plot()
# Out:
# Loading csv data for GBP

# %%
system.rawdata.daily_returns_volatility('EDOLLAR').plot()

# %%
len(system.rawdata.annualised_roll('EDOLLAR'))
# Out:
# 10761

# %%
system.rawdata.annualised_roll('EDOLLAR').plot()

# %%
system.rawdata.roll_differentials('EDOLLAR').plot()

# %%
system.rawdata.raw_futures_roll('EDOLLAR').plot()

# %%
system.rawdata.raw_futures_roll('EDOLLAR').head()
# Out:
#             raw_roll
# 1983-09-26     -0.20
# 1983-09-27     -0.21
# 1983-09-28     -0.21
# 1983-09-29     -0.24
# 1983-09-30     -0.27

# %%
system.rawdata.get_instrument_raw_carry_data('EDOLLAR').tail(1000)
# Out:
#                        PRICE   CARRY CARRY_CONTRACT PRICE_CONTRACT
# 2015-06-15 15:19:24  97.5425     NaN         201806         201809
# 2015-06-15 16:30:33  97.5175     NaN         201806         201809
# 2015-06-15 17:31:31  97.5075     NaN         201806         201809
# 2015-06-15 18:32:00  97.5025     NaN         201806         201809
# 2015-06-15 19:32:22  97.5075     NaN         201806         201809
# 2015-06-15 23:00:00  97.5150  97.620         201806         201809
# 2015-06-16 12:00:06  97.5475     NaN         201806         201809
# 2015-06-16 13:00:32  97.5525     NaN         201806         201809
# 2015-06-16 14:00:57  97.5475     NaN         201806         201809
# 2015-06-16 15:07:17  97.5325     NaN         201806         201809
# 2015-06-16 16:07:42  97.5375     NaN         201806         201809
# 2015-06-16 17:08:12  97.5525     NaN         201806         201809
# 2015-06-16 18:08:38  97.5625     NaN         201806         201809
# ...

# %%
instrument = 'EDOLLAR'
    edollar_carry = system.rules.get_raw_forecast(instrument, 'carry')
    edollar_carry.plot()
    pylab.show()
    edollar_pnl = system.accounts.pandl_for_instrument(instrument).cumsum()
    pd.concat([edollar_carry, edollar_pnl], 1).plot(title=instrument)

# %%
def look_carry(instrument):
    system = futures_system()
    carry = system.rules.get_raw_forecast(instrument, 'carry')
    carry.plot()
    pylab.show()
    pnl = system.accounts.pandl_for_instrument(instrument).cumsum()
    pd.concat([carry, pnl], 1).plot(title=instrument)

# %%
look_carry('EDOLLAR')
# Out:
# Calculating raw forecast EDOLLAR for carry
# Calculating daily volatility for EDOLLAR
# Calculating daily prices for EDOLLAR
# Calculating pandl for instrument for EDOLLAR
# Calculating notional position for EDOLLAR
# Calculating diversification multiplier
# Calculating clean instrument weights
# Calculating raw instrument weights
# Calculating subsystem position for EDOLLAR
# Calculating volatility scalar for EDOLLAR
# Calculating instrument value vol for EDOLLAR
# Calculating instrument currency vol for EDOLLAR
# Getting block value for EDOLLAR
# Getting fx rates for EDOLLAR
# Getting vol target
# Calculating combined forecast for EDOLLAR
# Calculating forecast weights for EDOLLAR
# Calculating raw forecast weights for EDOLLAR
# Calculating capped forecast for EDOLLAR carry
# Calculating diversification multiplier for EDOLLAR

# %%
look_carry('MXP')
# Out:
# Calculating raw forecast MXP for carry
# Loading csv carry data for MXP
# Calculating daily volatility for MXP
# Calculating daily prices for MXP
# Loading csv data for MXP
# Calculating pandl for instrument for MXP
# Loading csv data for MXP
# Calculating notional position for MXP
# Calculating diversification multiplier
# Calculating clean instrument weights
# Calculating raw instrument weights
# Calculating subsystem position for EDOLLAR
# Calculating volatility scalar for EDOLLAR
# Calculating instrument value vol for EDOLLAR
# Calculating instrument currency vol for EDOLLAR
# Getting block value for EDOLLAR
# Loading csv carry data for EDOLLAR
# Loading csv instrument config
# Calculating daily volatility for EDOLLAR
# Calculating daily prices for EDOLLAR
# Loading csv data for EDOLLAR
# Getting fx rates for EDOLLAR
# Getting vol target
# Loading csv instrument config
# Loading csv fx data
# Calculating combined forecast for EDOLLAR
# Calculating forecast weights for EDOLLAR
# ...

# %%
instrument = 'GAS_US'
edollar_carry = system.rules.get_raw_forecast(instrument, 'carry')
edollar_carry.plot()
pylab.show()
edollar_pnl = system.accounts.pandl_for_instrument(instrument).cumsum()
pd.concat([edollar_carry, edollar_pnl], 1).plot(title=instrument)
# Out:
# Calculating raw forecast GAS_US for carry
# Calculating daily volatility for GAS_US
# Calculating daily prices for GAS_US
# Calculating pandl for instrument for GAS_US
# Calculating notional position for GAS_US
# Calculating subsystem position for GAS_US
# Calculating volatility scalar for GAS_US
# Calculating instrument value vol for GAS_US
# Calculating instrument currency vol for GAS_US
# Getting block value for GAS_US
# Getting fx rates for GAS_US
# Calculating combined forecast for GAS_US
# Calculating forecast weights for GAS_US
# Calculating raw forecast weights for GAS_US
# Calculating capped forecast for GAS_US carry
# Calculating diversification multiplier for GAS_US
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-43f97a299615> in <module>()
#       3 edollar_carry.plot()
#       4 pylab.show()
# ...

# %%
system.rawdata.get_instrument_raw_carry_data('EDOLLAR')['CARRY_CONTRACT'].unique()
# Out:
# array(['198409', '198412', '198503', '198506', '198509', '198512',
#        '198603', '198606', '198609', '198612', '198703', '198706',
#        '198709', '198712', '198806', '198809', '198812', '198906',
#        '198909', '198912', '199003', '199006', '199009', '199012',
#        '199103', '199106', '199109', '199112', '199203', '199206',
#        '199209', '199212', '199303', '199306', '199309', '199312',
#        '199403', '199406', '199409', '199412', '199503', '199506',
#        '199509', '199512', '199603', '199606', '199609', '199612',
#        '199703', '199706', '199709', '199712', '199803', '199806',
#        '199809', '199812', '199903', '199906', '199909', '199912',
#        '200003', '200006', '200009', '200012', '200103', '200106',
#        '200109', '200112', '200203', '200206', '200209', '200212',
#        '200303', '200306', '200309', '200312', '200403', '200406',
#        '200409', '200412', '200503', '200506', '200509', '200512',
# ...

# %%
dir(system.rawdata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_protected',
#  'annualised_roll',
#  'daily_annualised_roll',
#  'daily_denominator_price',
#  'daily_returns',
#  'daily_returns_volatility',
#  'get_daily_percentage_volatility',
#  'get_daily_price',
#  'get_daily_prices',
#  'get_instrument_raw_carry_data',
#  'log',
#  'name',
#  'norm_returns',
#  'parent',
#  'raw_futures_roll',
#  'roll_differentials']

# %%
system.data.get_instrument_list()
# Out:
# ['CORN',
#  'LEANHOG',
#  'LIVECOW',
#  'SOYBEAN',
#  'WHEAT',
#  'KR10',
#  'KR3',
#  'BOBL',
#  'BTP',
#  'BUND',
#  'OAT',
#  'SHATZ',
#  'US10',
#  'US2',
#  'US20',
#  'US5',
#  'V2X',
#  'VIX',
#  'KOSPI',
#  'AEX',
#  'CAC',
#  'SMI',
#  'NASDAQ',
#  'SP500',
#  'AUD',
#  'EUR',
#  'GBP',
#  'JPY',
#  'MXP',
#  'NZD',
#  'COPPER',
#  'GOLD',
#  'PALLAD',
#  'PLAT',
#  'CRUDE_W',
#  'GAS_US',
#  'EDOLLAR',
#  'EUROSTX']

# %%
for instrument in system.data.get_instrument_list():
    system.rawdata.get_instrument_raw_carry_data(instrument).iloc[0:1000].plot(title=instrument)
# Out:
# C:\dev\bin\Anaconda\envs\pysys\lib\site-packages\matplotlib\pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
system.accounts.get_value_of_price_move('EDOLLAR')
# Out:
# Loading csv instrument config
# 2500

# %%
system.data.daily_prices('EDOLLAR').plot()
# Out:
# Loading csv data for EDOLLAR

# %%
system.data.get_value_of_block_price_move('EDOLLAR')
# Out:
# Loading csv instrument config
# 2500

# %%
portfolio.rolling_ann_std().plot()

# %%
portfolio.drawdown().plot()

# %%
portfolio.curve().plot()

# %%
system.rules.trading_rules()['carry']
# Out:
# TradingRule; function: <function carry at 0x000000000855F840>, data: rawdata.daily_annualised_roll, rawdata.daily_returns_volatility and other_args: smooth_days

# %%
system.rules.get_raw_forecast('EDOLLAR', 'carry').dropna().plot()
